# %%
from utils.inferencia_ocr import PlateOCR
import utils.plots as plots
import cv2

# %%
onnx_path_me = 'onnx_models/plate_ocr_me.onnx'
me_ocr = PlateOCR(onnx_path_me)

# %%
onnx_path_br = 'onnx_models/plate_ocr_br.onnx'
br_ocr = PlateOCR(onnx_path_br)

# %%
imgpath = 'datasets/dataset1/placas/val/img_000002.jpg'
img = cv2.imread(imgpath, cv2.IMREAD_GRAYSCALE)
plots.show_image(img)

# %%
img
# Out:
# array([[  0,   0,   0, ..., 231, 229, 227],
#        [  0,   0,   0, ..., 231, 229, 227],
#        [  0,   0,   0, ..., 231, 229, 228],
#        ...,
#        [  0,   0,   0, ..., 206, 201, 198],
#        [  0,   0,   0, ..., 201, 195, 191],
#        [  0,   0,   0, ..., 195, 189, 184]], dtype=uint8)

# %%
br_ocr(img, layout='BR')
# Out:
# ('PPC5431', 0.7723933758875957)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
